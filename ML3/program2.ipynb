# %%
### Linear Regression

# %%
### import required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### load the data

# %%
df = pd.read_csv("C:\\Users\\sainya.vishwakarma\\Python\\ML3\\Position_Salaries.csv")
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
df.isna().sum()
# Out:
# Position    0
# Level       0
# Salary      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     str
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), str(1)
# memory usage: 372.0 bytes

# %%
df.describe()
# Out:
#           Level          Salary
# count  10.00000       10.000000
# mean    5.50000   249500.000000
# std     3.02765   299373.883668
# min     1.00000    45000.000000
# 25%     3.25000    65000.000000
# 50%     5.50000   130000.000000
# 75%     7.75000   275000.000000
# max    10.00000  1000000.000000

# %%
# since the position and level have same info lets remove the position column

df.drop(['Position'],axis = 1, inplace = True)

# %%
df
# Out:
#    Level   Salary
# 0      1    45000
# 1      2    50000
# 2      3    60000
# 3      4    80000
# 4      5   110000
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
df.corr()
# Out:
#            Level    Salary
# Level   1.000000  0.817949
# Salary  0.817949  1.000000

# %%
sns.pairplot(df)

# %%
x = df.drop(['Salary'], axis =1)
y = df['Salary']

# %%
from sklearn.linear_model import LinearRegression

# create the model

model = LinearRegression()

# fit the model

model.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x)
r2s = r2_score(y,y_pred)
print(f"r2 score:{r2s:.2f}")
# Out:
# r2 score:0.67

# %%
#plot the data
plt.scatter(x['Level'],y,label="Salary")

#plot the regression line
plt.scatter(x['Level'],y_pred,color="Red")
plt.plot(x['Level'],y_pred,color="Red",label="Regression Line")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.title("Polynomial Regression")
plt.grid()
plt.legend()
