# %% [markdown]
# ### Bagging Algorithm(Random Forest)

# %% [markdown]
# ## problem statement
# - predict if patient will suffer with heart disease
# - target will be the dependent variable

# %% [markdown]
# ## import required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## load the dataset

# %%
df = pd.read_csv("C:\\Users\\sainya.vishwakarma\\Python\\Ensemble Learning\\heart_disease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### exploratory data analysis

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### find the correlation analysis

# %%
df.corr()['target'].sort_values()
# Out:
# exang      -0.436757
# oldpeak    -0.430696
# ca         -0.391724
# thal       -0.344029
# sex        -0.280937
# age        -0.225439
# trestbps   -0.144931
# chol       -0.085239
# fbs        -0.028046
# restecg     0.137230
# slope       0.345877
# thalach     0.421741
# cp          0.433798
# target      1.000000
# Name: target, dtype: float64

# %% [markdown]
# ### split the dataset into x and y

# %%
x = df.drop('target',axis=1)
y=df['target']

# %% [markdown]
# ### split the data into train and test dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %% [markdown]
# ### train the models

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10,max_depth=3) # 100 trees
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

y_pred = model.predict(x_train)
accuracy = accuracy_score(y_train,y_pred)
precision = precision_score(y_train,y_pred)
recall = recall_score(y_train,y_pred)
f1 = f1_score(y_train,y_pred)

print(f'accuracy: {accuracy:.2f}')
print(f'precision: {precision:.2f}')
print(f'recall: {recall:.2f}')
print(f'f1 score: {f1:.2f}')
# Out:
# accuracy: 0.87
# precision: 0.87
# recall: 0.90
# f1 score: 0.88

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)

print(f'accuracy: {accuracy:.2f}')
print(f'precision: {precision:.2f}')
print(f'recall: {recall:.2f}')
print(f'f1 score: {f1:.2f}')
# Out:
# accuracy: 0.84
# precision: 0.84
# recall: 0.86
# f1 score: 0.85

# %%
# find the important features
pd.DataFrame(model.feature_importances_,index=x.columns,columns=['Importance']).sort_values('Importance')
# Out:
#           Importance
# restecg     0.000000
# fbs         0.000000
# chol        0.015595
# trestbps    0.020546
# slope       0.032283
# sex         0.034127
# age         0.038875
# thalach     0.078311
# thal        0.103344
# cp          0.110857
# exang       0.169098
# ca          0.197752
# oldpeak     0.199212

# %% [markdown]
# ### result visualization

# %%
sns.scatterplot(x_test,x='age',y='chol',hue=y_pred)
plt.grid(alpha=0.3)
