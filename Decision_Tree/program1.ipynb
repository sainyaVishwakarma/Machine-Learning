# %% [markdown]
# ### Binary Classification

# %% [markdown]
# ## Problem Statement
# - predict if patient will suffer with hearing disease
# - test_result will the dependent var while age and physical_score will be the independent variable

# %% [markdown]
# ## import required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## load the dataset

# %%
df = pd.read_csv("C:\\Users\\sainya.vishwakarma\\Python\\Decision_Tree\\hearing_test.csv")
df
# Out:
#        age  physical_score  test_result
# 0     33.0            40.7            1
# 1     50.0            37.2            1
# 2     52.0            24.7            0
# 3     56.0            31.0            0
# 4     35.0            42.9            1
# ...    ...             ...          ...
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1
#
# [5000 rows x 3 columns]

# %% [markdown]
# ### get the info of dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             5000 non-null   float64
#  1   physical_score  5000 non-null   float64
#  2   test_result     5000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 117.3 KB

# %% [markdown]
# ### get the statistical info of dataset

# %%
df.describe()
# Out:
#                age  physical_score  test_result
# count  5000.000000     5000.000000  5000.000000
# mean     51.609000       32.760260     0.600000
# std      11.287001        8.169802     0.489947
# min      18.000000       -0.000000     0.000000
# 25%      43.000000       26.700000     0.000000
# 50%      51.000000       35.300000     1.000000
# 75%      60.000000       38.900000     1.000000
# max      90.000000       50.000000     1.000000

# %% [markdown]
# ### find the correlation analysis

# %%
df.corr()
# Out:
#                      age  physical_score  test_result
# age             1.000000       -0.782146    -0.683171
# physical_score -0.782146        1.000000     0.792716
# test_result    -0.683171        0.792716     1.000000

# %% [markdown]
# ### visualiza the relationship

# %%
sns.pairplot(df)

# %% [markdown]
# ### check if any missing value

# %%
df.isna().sum()
# Out:
# age               0
# physical_score    0
# test_result       0
# dtype: int64

# %% [markdown]
# ### check if dataset is imbalanced

# %%
df['test_result'].value_counts()
# Out:
# test_result
# 1    3000
# 0    2000
# Name: count, dtype: int64

# %% [markdown]
# ### split the dataset into x and y

# %%
x = df.drop('test_result',axis=1)
y=df['test_result']

# %% [markdown]
# ### split the data into train and test dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %% [markdown]
# ### train the model

# %%
from sklearn.tree import DecisionTreeClassifier

# create the model
model = DecisionTreeClassifier(max_depth=3)

# fit the model
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ### evaluate the model

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

y_pred = model.predict(x_train)
accuracy = accuracy_score(y_train,y_pred)
precision = precision_score(y_train,y_pred)
recall = recall_score(y_train,y_pred)
f1 = f1_score(y_train,y_pred)

print(f'accuracy: {accuracy:.2f}')
print(f'precision: {precision:.2f}')
print(f'recall: {recall:.2f}')
print(f'f1 score: {f1:.2f}')
# Out:
# accuracy: 0.93
# precision: 0.93
# recall: 0.95
# f1 score: 0.94

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)

print(f'accuracy: {accuracy:.2f}')
print(f'precision: {precision:.2f}')
print(f'recall: {recall:.2f}')
print(f'f1 score: {f1:.2f}')
# Out:
# accuracy: 0.91
# precision: 0.92
# recall: 0.94
# f1 score: 0.93

# %% [markdown]
# ### visualize the tree

# %%
from sklearn.tree import plot_tree

_ = plot_tree(model,feature_names=['age','physical score'],class_names =['No','Yes'],fontsize=6,filled=True)
